# %% [markdown]
# # Code to analyse car make using ChatGPT
#
# This code was setup in Google Colab to free-up local resouces and to allow for the code to run for longer periods of time.

# %% [markdown]
# Loading Data from Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/AI/
# Out:
# /content/drive/My Drive/AI

# %% [markdown]
# Add auth key

# %%
authkey = ""

# %%
# !pip install openai==0.28.1
# Out:
# Collecting openai==0.28.1
#   Downloading openai-0.28.1-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.28.1) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.28.1) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.28.1) (3.8.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28.1) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.1) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.1) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.1) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.1) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.1) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.1) (1.3.1)
# Installing collected packages: openai
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# Successfully installed openai-0.28.1

# %% [markdown]
# # ChatGPT
#
# For analysis

# %%
# https://help.openai.com/en/articles/6654000-best-practices-for-prompt-engineering-with-openai-api

import openai
import json
import time

# Set OpenAI API key
openai.api_key = authkey

def GPTextract(prompt, model="gpt-3.5-turbo"):
    ''' Extracts data from unstructured text based on the topic and output value type.
    prompt: string
    topic: string
    output_value_type: string
    topic_add: string
    model: string

    return: dictionary
    '''

    retries = 3
    while retries > 0:
        try:
            messages = [
                {"role": "system", "content":
                '''
                You are a powerful design analyst looking at car make's brand image.
                You are tasked to extract design keywords and present it as a comma separated text.

                Do not deviate from the output tags.

                Input: Back in the olden days, a tuning house that mainly made Fiats go faster. Nowadays, a tuning house that mainly makes Fiats go faster. Part of the Stellantis empire, Abarth today mostly serves up Fiat 500s tuned to various degrees of absurdity. If you view ‘cartoonish’ as a compliment rather than an insult, you’ll be right at home here.
                Abarth A former motorsport team and independent tuning company, Abarth is now owned by Fiat and responsible for the firm’s sportiest cars. In recent years, Fiat has even tried to establish Abarth as a standalone brand – in the same way that Citroën has split off its DS luxury division. However, the major difference is that DS cars look completely different from the Citroëns on which they’re based, whereas Abarths rely on bodykits and big wheels to mark them out. The Abarth 595, for example, is a beefed-up Fiat 500 hatchback, while the Abarth 124 Spider is a hotter version of its Fiat namesake

                Output: Cartoonish, Sporty,
                '''
                },
                {"role": "user", "content": prompt}
                ]
            response = openai.ChatCompletion.create(
                model=model, # gpt-3.5-turbo
                messages=messages, # prompt
                temperature=0, # temperature 0 means deterministic, 1 means random
            )
            text = response.choices[0].message["content"]
            text = text.replace("\n","")
            return text
        except Exception as e:
            if e:
                print(e)
                print('Timeout error, retrying...')
                retries -= 1
                time.sleep(5)
            else:
                raise e

    print('API is not responding, moving on...')
    return None

# %%
import pandas as pd
import datetime

def process_dataframe(progress_file):

    # Load progress if it exists
    progress_df = pd.read_csv(progress_file)
    # start_index = progress_df[df.columns[3]].last_valid_index() + 1
    start_index = 26
    print(f"Resuming from index {start_index}")

    start_time = datetime.datetime.now().strftime("%H:%M:%S")
    prev_time = datetime.datetime.now()
    print(f"Start processing at {start_time}")
    count = 0
    for index, row in progress_df.iloc[start_index:].iterrows():
        print(index,":", progress_df.iloc[index,0], end = " ")
        if pd.isna(row.iloc[2]):
          try:
              # Process the value in the 2nd column (index 1)
              if (row.iloc[1] != "") and not(pd.isna(row.iloc[1])):
                # Save the output in the 4th column (index 3)
                output = GPTextract(row.iloc[1],"gpt-4")
                # output = GPTextract(row.iloc[1],"gpt-3.5-turbo-1106")
                progress_df.at[index, progress_df.columns[2]] = output
                if index % 1 == 0:  # Save every row
                    progress_df.to_csv(progress_file, index=False)
                    print("(Saved)")
                    count+=1

          except Exception as e:
              print(f"Error processing row {index}: {e}")
              continue

        else:
          print("(Skip)")

        if count == 10:
            # show timestamp in minutes
            duration = datetime.datetime.now() - prev_time
            duration = duration.total_seconds() / 60

            #print timestamp every 10 rows
            print("Current:",datetime.datetime.now().strftime("%H:%M:%S"), "Duration (mins):", duration )
            prev_time = datetime.datetime.now()
            count = 0

    print("Processing complete. Output saved.")

# %%
process_dataframe("brand_info.csv")
# Out:
# Resuming from index 26
# Start processing at 02:52:48
# 26 : FIAT (Saved)
# 27 : FISKER (Saved)
# 28 : FORD (Saved)
# 29 : GEELY (Saved)
# 30 : GENESIS (Saved)
# 31 : GMC (Saved)
# 32 : GORDON MURRAY Automotive (Saved)
# 33 : HINDUSTAN (Saved)
# 34 : HOLDEN (Saved)
# 35 : HONDA (Saved)
# Current: 02:53:10 Duration (mins): 0.36933173333333336
# 36 : HYUNDAI (Saved)
# 37 : INEOS (Saved)
# 38 : INFINITI (Saved)
# 39 : ISUZU Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9012, Requested 1184. Please try again in 1.176s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 40 : JAGUAR Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9055, Requested 1427. Please try again in 2.892s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 41 : JEEP Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9228, Requested 1274. Please try again in 3.012s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 42 : Karma (Saved)
# 43 : KIA Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9497, Requested 1269. Please try again in 4.596s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 44 : KOENIGSEGG Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9620, Requested 1057. Please try again in 4.062s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 45 : KTM Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9343, Requested 728. Please try again in 426ms. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# Current: 02:54:00 Duration (mins): 0.8345762166666667
# 46 : LADA Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9014, Requested 1266. Please try again in 1.68s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 47 : LAMBORGHINI Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9184, Requested 2004. Please try again in 7.128s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 8341, Requested 2004. Please try again in 2.07s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 48 : LANCIA (Saved)
# 49 : LAND ROVER Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9522, Requested 1330. Please try again in 5.112s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 8674, Requested 1330. Please try again in 24ms. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 50 : LEXUS Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 8907, Requested 1208. Please try again in 690ms. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 51 : LIGHTYEAR (Saved)
# 52 : LINCOLN Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9627, Requested 1229. Please try again in 5.136s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 8780, Requested 1229. Please try again in 54ms. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 53 : LOTUS (Saved)
# 54 : Lucid Motors (Saved)
# 55 : Mahindra (Saved)
# Current: 02:55:03 Duration (mins): 1.0506267166666665
# 56 : MARUTI SUZUKI Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9832, Requested 342. Please try again in 1.044s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 57 : MASERATI Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9069, Requested 1457. Please try again in 3.156s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 58 : MAZDA Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9365, Requested 1186. Please try again in 3.306s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 59 : MCLAREN Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9380, Requested 1073. Please try again in 2.718s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 60 : Mercedes-AMG Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9063, Requested 1385. Please try again in 2.688s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 61 : MERCEDES BENZ Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9356, Requested 2662. Please try again in 12.108s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 8511, Requested 2662. Please try again in 7.038s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 7642, Requested 2662. Please try again in 1.824s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# API is not responding, moving on...
# (Saved)
# 62 : MG (Saved)
# 63 : MINI (Saved)
# 64 : MITSUBISHI (Saved)
# 65 : MORGAN (Saved)
# Current: 02:56:09 Duration (mins): 1.1027814333333334
# 66 : NIO Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9027, Requested 1427. Please try again in 2.724s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 67 : NISSAN Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9040, Requested 1095. Please try again in 810ms. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 68 : OPEL Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 8898, Requested 1422. Please try again in 1.92s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 69 : PAGANI Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9203, Requested 1129. Please try again in 1.992s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 70 : PANOZ (Saved)
# 71 : PERODUA Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9507, Requested 1261. Please try again in 4.608s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 72 : PEUGEOT Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9524, Requested 1479. Please try again in 6.018s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 8681, Requested 1479. Please try again in 960ms. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 73 : Pininfarina (Saved)
# 74 : Polestar (Saved)
# 75 : PORSCHE Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9336, Requested 1286. Please try again in 3.732s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# Current: 02:57:10 Duration (mins): 1.0222537166666668
# 76 : PROTON Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9471, Requested 933. Please try again in 2.424s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 77 : QOROS (Saved)
# 78 : RAM Trucks Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9633, Requested 603. Please try again in 1.416s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 79 : RENAULT Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9199, Requested 1699. Please try again in 5.388s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 8353, Requested 1699. Please try again in 312ms. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 80 : RIMAC (Saved)
# 81 : RIVIAN (Saved)
# 82 : ROLLS-ROYCE (Saved)
# 83 : SAAB Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9119, Requested 1020. Please try again in 834ms. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 84 : SANTANA (Saved)
# 85 : SEAT Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9554, Requested 1100. Please try again in 3.924s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# Current: 02:58:12 Duration (mins): 1.0239145833333334
# 86 : SKODA Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9515, Requested 1147. Please try again in 3.971s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 87 : SMART Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9622, Requested 951. Please try again in 3.438s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 88 : SPYKER Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9517, Requested 826. Please try again in 2.058s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 89 : SUBARU Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9120, Requested 933. Please try again in 318ms. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 90 : SUZUKI (Saved)
# 91 : TATA MOTORS Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9352, Requested 1025. Please try again in 2.262s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 92 : TOYOTA Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9060, Requested 1225. Please try again in 1.71s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 93 : TVR Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9126, Requested 1087. Please try again in 1.278s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 94 : VAUXHALL Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 8962, Requested 1107. Please try again in 414ms. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 95 : VinFast (Saved)
# Current: 02:59:14 Duration (mins): 1.0436687166666667
# 96 : VOLKSWAGEN Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9166, Requested 1233. Please try again in 2.394s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 97 : VOLVO Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9308, Requested 1590. Please try again in 5.388s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 8465, Requested 1590. Please try again in 330ms. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# 98 : WIESMANN (Saved)
# 99 : Xpeng (Saved)
# 100 : Zenvo Rate limit reached for gpt-4 in organization org-oRwo7HlIEyRavqNVw1ukShCz on tokens per min (TPM): Limit 10000, Used 9567, Requested 613. Please try again in 1.08s. Visit https://platform.openai.com/account/rate-limits to learn more.
# Timeout error, retrying...
# (Saved)
# Processing complete. Output saved.
